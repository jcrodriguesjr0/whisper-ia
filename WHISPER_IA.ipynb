# %% [markdown]
# <a href="https://colab.research.google.com/github/jcrodriguesjr0/whisper-ia/blob/main/WHISPER_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🎙️ OpenAI Whisper - Transcrição Automática de Áudio
#
# Este notebook foi desenvolvido para apresentar a utilização do modelo **Whisper** (da OpenAI) focado em **Speech-to-Text**. Trata-se de um sistema inteligente capaz de ouvir áudios e convertê-los em texto altamente acurado, rodando via CLI.
#
# ---

# %% [markdown]
# ### 📦 Passo 1: Instalação das Dependências
# Instalamos a biblioteca base do `openai-whisper` e a engine do `ffmpeg` (ferramenta que lida com extração e decodificação do áudio).

# %%
# !pip install -U openai-whisper
# !sudo apt update && sudo apt install ffmpeg

# %% [markdown]
# ### 🚀 Passo 2: Executando a Transcrição do Arquivo
# Faça o upload do seu áudio na aba de arquivos do Colab (nomeie como `arquivo.mp3`).
#
# - **Modelo:** Utilizamos o `--model tiny` para maior velocidade de inferência.
# - **Contexto:** Adicionamos um `--initial_prompt` ensinando a IA a utilizar a ortografia correta e o contexto do português brasileiro ao ditar o texto.

# %%
# !whisper "arquivo.mp3" --model tiny --language pt --task transcribe --initial_prompt "Transcrição em português do Brasil, com ortografia brasileira."
